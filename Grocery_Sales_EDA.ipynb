# %%
import pandas as pd

# %% [markdown]
# Sheets - 7
#
# Useful - Cities, Countries, Customer, Products, Sales

# %%
df = pd.read_csv(r"E:\Coding Progs\Python programmes\DataAnalysisProjects\GrocerySales_Analysis\Data\Raw\sales.csv")
df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       0.0
# 1        2             16       25011         61         7       0.0
# 2        3             13       94024         23        24       0.0
# 3        4              8       73966        176        19       0.2
# 4        5             10       32653        310         9       0.0
#
#    TotalPrice                SalesDate     TransactionNumber
# 0         0.0  2018-02-05 07:38:25.430  FQL4S94E4ME1EZFTG42G
# 1         0.0  2018-02-02 16:03:31.150  12UGLX40DJ1A5DTFBHB8
# 2         0.0  2018-05-03 19:31:56.880  5DT8RCPL87KI5EORO7B0
# 3         0.0  2018-04-07 14:43:55.420  R3DR9MLD5NR76VO17ULE
# 4         0.0  2018-02-12 15:37:03.940  4BGS0Z5OMAZ8NDAFHHP3

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6758125 entries, 0 to 6758124
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   SalesID            int64
#  1   SalesPersonID      int64
#  2   CustomerID         int64
#  3   ProductID          int64
#  4   Quantity           int64
#  5   Discount           float64
#  6   TotalPrice         float64
#  7   SalesDate          object
#  8   TransactionNumber  object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 464.0+ MB
#             SalesID  SalesPersonID    CustomerID     ProductID      Quantity  \
# count  6.758125e+06   6.758125e+06  6.758125e+06  6.758125e+06  6.758125e+06
# mean   3.379063e+06   1.199972e+01  4.939567e+04  2.265474e+02  1.300401e+01
# std    1.950903e+06   6.632689e+00  2.850504e+04  1.304744e+02  7.209701e+00
# min    1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# ...

# %% [markdown]
# Total price needs to be calculated
#
# -->  Quantity(from sales)* Price(from Products)

# %%
df_Products = pd.read_csv(r"E:\Coding Progs\Python programmes\DataAnalysisProjects\GrocerySales_Analysis\Data\Raw\products.csv")
df_Products.info()
df_Products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     452 non-null    int64
#  1   ProductName   452 non-null    object
#  2   Price         452 non-null    float64
#  3   CategoryID    452 non-null    int64
#  4   Class         452 non-null    object
#  5   ModifyDate    452 non-null    object
#  6   Resistant     452 non-null    object
#  7   IsAllergic    452 non-null    object
#  8   VitalityDays  452 non-null    float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 31.9+ KB
#    ProductID                 ProductName    Price  CategoryID   Class  \
# 0          1         Flour - Whole Wheat  74.2988           3  Medium
# 1          2  Cookie Chocolate Chip With  91.2329           3  Medium
# 2          3          Onions - Cippolini   9.1379           9  Medium
# ...

# %%
df_merged = df.merge(df_Products, on='ProductID', how='left')
Total_Price = df_merged['Quantity']*df_merged['Price']

# %% [markdown]
# Verify Total_Price Values

# %%
df_merged[['ProductID', 'Quantity', 'Price']] , Total_Price
# Out:
# (         ProductID  Quantity    Price
#  0              381         7  44.2337
#  1               61         7  62.5460
#  2               23        24  79.0184
#  3              176        19  81.3167
#  4              310         9  79.9780
#  ...            ...       ...      ...
#  6758120        300        13  69.5694
#  6758121        452        22  28.5653
#  6758122        405        18   0.4278
#  6758123        104        23  98.2471
#  6758124        305        12  91.0997
#
#  [6758125 rows x 3 columns],
#  0           309.6359
#  1           437.8220
#  2          1896.4416
#  3          1545.0173
#  4           719.8020
#               ...
#  6758120     904.4022
#  6758121     628.4366
#  6758122       7.7004
#  6758123    2259.6833
#  6758124    1093.1964
#  Length: 6758125, dtype: float64)

# %% [markdown]
# Assign values to the sales df

# %%
df['TotalPrice'] = Total_Price
df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       0.0
# 1        2             16       25011         61         7       0.0
# 2        3             13       94024         23        24       0.0
# 3        4              8       73966        176        19       0.2
# 4        5             10       32653        310         9       0.0
#
#    TotalPrice                SalesDate     TransactionNumber
# 0    309.6359  2018-02-05 07:38:25.430  FQL4S94E4ME1EZFTG42G
# 1    437.8220  2018-02-02 16:03:31.150  12UGLX40DJ1A5DTFBHB8
# 2   1896.4416  2018-05-03 19:31:56.880  5DT8RCPL87KI5EORO7B0
# 3   1545.0173  2018-04-07 14:43:55.420  R3DR9MLD5NR76VO17ULE
# 4    719.8020  2018-02-12 15:37:03.940  4BGS0Z5OMAZ8NDAFHHP3

# %%
# df.to_csv(r"E:\Coding Progs\Python programmes\DataAnalysisProjects\Not Decided\ProcessedSales.csv", index=False)

# %% [markdown]
# FURTHER Transformations in PowerBI
